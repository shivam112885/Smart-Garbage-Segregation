# %% [markdown]
# # IMPORTING TENSORFLOW

# %%
# !pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in ./.local/lib/python3.9/site-packages (2.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.local/lib/python3.9/site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: six>=1.12.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/intelpython/python3.9/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in ./.local/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.local/lib/python3.9/site-packages (from tensorflow) (15.0.6.1)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.local/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in ./.local/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in ./.local/lib/python3.9/site-packages (from tensorflow) (2.11.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./.local/lib/python3.9/site-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: numpy>=1.20 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/intelpython/python3.9/lib/python3.9/site-packages (from tensorflow) (1.22.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.local/lib/python3.9/site-packages (from tensorflow) (1.51.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in ./.local/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./.local/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: flatbuffers>=2.0 in ./.local/lib/python3.9/site-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.local/lib/python3.9/site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: h5py>=2.9.0 in ./.local/lib/python3.9/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.local/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: setuptools in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/intelpython/python3.9/lib/python3.9/site-packages (from tensorflow) (63.4.1)
# Requirement already satisfied: packaging in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/intelpython/python3.9/lib/python3.9/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in ./.local/lib/python3.9/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: astunparse>=1.6.0 in ./.local/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in ./.local/lib/python3.9/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/intelpython/python3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in ./.local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in ./.local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./.local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.16.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.2.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in ./.local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in ./.local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/intelpython/python3.9/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.28.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/intelpython/python3.9/lib/python3.9/site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.local/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.local/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.local/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.local/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/intelpython/python3.9/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (6.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/intelpython/python3.9/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/intelpython/python3.9/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/intelpython/python3.9/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/intelpython/python3.9/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.local/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /glob/development-tools/versions/oneapi/2023.0.1/oneapi/intelpython/python3.9/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (3.12.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in ./.local/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.local/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)

# %% [markdown]
# # IMPORTING TENSORFLOW

# %%
import tensorflow as tf

# %% [markdown]
# # USING CPU

# %%
device = "/device:CPU:0"

# %% [markdown]
# # DATA IMPORTING

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
import math

dir_example = "Data"

classes = os.listdir(dir_example)
print(classes)
# Out:
# ['Test', 'Train']

# %%
dir_example = "Data/Train"

train_classes = os.listdir(dir_example)
print(train_classes)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %% [markdown]
# # DATA VISUALIZATION

# %%
dir_with_examples = 'visualize'
files_per_row = 6
files_in_dir = os.listdir(dir_with_examples)
number_of_cols = files_per_row
number_of_rows = int(len(files_in_dir) / number_of_cols)

# Generate the subplots
fig, axs = plt.subplots(number_of_rows, number_of_cols)
fig.set_size_inches(20, 15, forward=True)

# Map each file to subplot
try:
  for i in range(0, len(files_in_dir)):
    file_name = files_in_dir[i]
    image = Image.open(f'{dir_with_examples}/{file_name}')
    row = math.floor(i / files_per_row)
    col = i % files_per_row
    axs[col].imshow(image)
    axs[col].axis('off')
except:
  pass
# Show the plot
plt.show()

# %%
from tensorflow.keras.models import Sequential
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Dropout, SpatialDropout2D
from tensorflow.keras.losses import sparse_categorical_crossentropy, binary_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # PREPARING OF DATA

# %%
train = 'Data/Train'
test = 'Data/Test'

# %%
train_generator = ImageDataGenerator(rescale = 1/255)

train_generator = train_generator.flow_from_directory(train,
                                                      target_size = (300,300),
                                                      batch_size = 32,
                                                      class_mode = 'sparse')

labels = (train_generator.class_indices)
print(labels,'\n')

labels = dict((v,k) for k,v in labels.items())
print(labels)
# Out:
# Found 2186 images belonging to 6 classes.
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}
#
# {0: 'cardboard', 1: 'glass', 2: 'metal', 3: 'paper', 4: 'plastic', 5: 'trash'}

# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\lenovo\miniconda3\envs\smart-dustbin\lib\site-packages (12.2.0)

# %%
from PIL import Image

# %%
# !pip uninstall pillow -y
# Out:
# WARNING: Skipping pillow as it is not installed.

# %%
# !pip install Image
# Out:
# Collecting Image
#   Downloading image-1.5.33.tar.gz (15 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pillow (from Image)
#   Using cached pillow-12.2.0-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Collecting django (from Image)
#   Downloading django-5.2.12-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in c:\users\lenovo\miniconda3\envs\smart-dustbin\lib\site-packages (from Image) (1.17.0)
# Collecting asgiref>=3.8.1 (from django->Image)
#   Downloading asgiref-3.11.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting sqlparse>=0.3.1 (from django->Image)
#   Downloading sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting tzdata (from django->Image)
#   Downloading tzdata-2026.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: typing_extensions>=4 in c:\users\lenovo\miniconda3\envs\smart-dustbin\lib\site-packages (from asgiref>=3.8.1->django->Image) (4.15.0)
# Downloading django-5.2.12-py3-none-any.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.3 MB 3.1 MB/s eta 0:00:03
#    ------- -------------------------------- 1.6/8.3 MB 2.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.1/8.3 MB 3.0 MB/s eta 0:00:03
#    ------------- -------------------------- 2.9/8.3 MB 3.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.7/8.3 MB 3.3 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.3 MB 3.4 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.3 MB 3.4 MB/s eta 0:00:01
#    -------------------------- ------------- 5.5/8.3 MB 3.4 MB/s eta 0:00:01
#    -------------------------------- ------- 6.8/8.3 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------- -- 7.9/8.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 3.5 MB/s  0:00:02
# Downloading asgiref-3.11.1-py3-none-any.whl (24 kB)
# Downloading sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Using cached pillow-12.2.0-cp310-cp310-win_amd64.whl (7.1 MB)
# Downloading tzdata-2026.1-py2.py3-none-any.whl (348 kB)
# Building wheels for collected packages: Image
#   Building wheel for Image (pyproject.toml): started
#   Building wheel for Image (pyproject.toml): finished with status 'done'
#   Created wheel for Image: filename=image-1.5.33-py2.py3-none-any.whl size=19563 sha256=98367f7f1e833fe50e9a77502e9d3a018582f0f40b3f8413057bacd18cec19b0
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\70\0c\a4\7cfa53a5c6225c2db2bfec08e782b43d0f25fdae2e995b69be
# Successfully built Image
# Installing collected packages: tzdata, sqlparse, pillow, asgiref, django, Image
#
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ------ --------------------------------- 1/6 [sqlparse]
#    ------------- -------------------------- 2/6 [pillow]
#    ------------- -------------------------- 2/6 [pillow]
#    ------------- -------------------------- 2/6 [pillow]
#    ------------- -------------------------- 2/6 [pillow]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    -------------------------- ------------- 4/6 [django]
#    --------------------------------- ------ 5/6 [Image]
#    ---------------------------------------- 6/6 [Image]
#
# Successfully installed Image-1.5.33 asgiref-3.11.1 django-5.2.12 pillow-12.2.0 sqlparse-0.5.5 tzdata-2026.1

# %%
import PIL.Image

# %%
for image_batch, label_batch in train_generator:
  break
image_batch.shape, label_batch.shape
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 for image_batch, label_batch in train_generator:
#       2   break
#       3 image_batch.shape, label_batch.shape
#
# File c:\Users\Lenovo\miniconda3\envs\smart-dustbin\lib\site-packages\keras\src\legacy\preprocessing\image.py:115, in Iterator.__next__(self)
#     112     index_array = next(self.index_generator)
#     113 # The transformation of images is not under thread lock
#     114 # so it can be done in parallel
# --> 115 return self._get_batches_of_transformed_samples(index_array)
#
# File c:\Users\Lenovo\miniconda3\envs\smart-dustbin\lib\site-packages\keras\src\legacy\preprocessing\image.py:316, in BatchFromFilesMixin._get_batches_of_transformed_samples(self, index_array)
#     314 filepaths = self.filepaths
#     315 for i, j in enumerate(index_array):
# --> 316     img = image_utils.load_img(
#     317         filepaths[j],
#     318         color_mode=self.color_mode,
#     319         target_size=self.target_size,
#     320         interpolation=self.interpolation,
#     321         keep_aspect_ratio=self.keep_aspect_ratio,
#     322     )
#     323     x = image_utils.img_to_array(img, data_format=self.data_format)
#     324     # Pillow images should be closed after `load_img`,
#     325     # but not PIL images.
#
# File c:\Users\Lenovo\miniconda3\envs\smart-dustbin\lib\site-packages\keras\src\utils\image_utils.py:227, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     195 """Loads an image into PIL format.
#     196
#     197 Example:
#    (...)
#     224     A PIL Image instance.
#     225 """
#     226 if pil_image is None:
# --> 227     raise ImportError(
#     228         "Could not import PIL.Image. The use of `load_img` requires PIL."
#     229     )
#     230 if isinstance(path, io.BytesIO):
#     231     img = pil_image.open(path)
#
# ImportError: Could not import PIL.Image. The use of `load_img` requires PIL.

# %%
test_generator = ImageDataGenerator(rescale = 1./255)

test_generator = test_generator.flow_from_directory(test,
                                                    target_size = (300,300),
                                                    batch_size = 32,
                                                    class_mode = 'sparse')

test_labels = (test_generator.class_indices)
print(test_labels,'\n')

test_labels = dict((v,k) for k,v in test_labels.items())
print(test_labels)
# Out:
# Found 343 images belonging to 6 classes.
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}
#
# {0: 'cardboard', 1: 'glass', 2: 'metal', 3: 'paper', 4: 'plastic', 5: 'trash'}

# %% [markdown]
# # Importing oneDNN

# %%
import oneDNN as dnn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 import oneDNN as dnn
#
# ModuleNotFoundError: No module named 'oneDNN'

# %% [markdown]
# # LABELING

# %%
print(train_generator.class_indices)
Labels = '\n'.join(sorted(train_generator.class_indices.keys()))

with open('Labels.txt', 'w') as file:
  file.write(Labels)
# Out:
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}

# %% [markdown]
# # CREATING MODEL WITH oneDNN OPTIMIZATION

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '1'

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()

# Convolution blocks
model.add(Conv2D(32, kernel_size=(3,3), padding='same', input_shape=(300,300,3), activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))

# Classification layers
model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))

model.add(Dropout(0.2))
model.add(Dense(6, activation='softmax'))

# %% [markdown]
# # COMPILING MODEL  # Enable OneDNN optimizations

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 300, 300, 32)      896
#
#  max_pooling2d_24 (MaxPoolin  (None, 150, 150, 32)     0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 150, 150, 64)      18496
#
#  max_pooling2d_25 (MaxPoolin  (None, 75, 75, 64)       0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 75, 75, 32)        18464
#
#  max_pooling2d_26 (MaxPoolin  (None, 37, 37, 32)       0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 43808)             0
#
#  dense_24 (Dense)            (None, 64)                2803776
#
#  dropout_16 (Dropout)        (None, 64)                0
#
#  dense_25 (Dense)            (None, 32)                2080
#
#  dropout_17 (Dropout)        (None, 32)                0
#
#  dense_26 (Dense)            (None, 6)                 198
#
# =================================================================
# Total params: 2,843,910
# Trainable params: 2,843,910
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # TRAINING THE MODEL(10 EPOCHS)

# %%
model.fit_generator(train_generator,
          epochs=10,
          steps_per_epoch=2184//32)
# Out:
# /home/u187876/tmp/ipykernel_2277750/3549247296.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train_generator,
# Epoch 1/10
# 68/68 [==============================] - 70s 969ms/step - loss: 1.6803 - accuracy: 0.3146
# 68/68 [==============================] - 52s 764ms/step - loss: 1.4176 - accuracy: 0.4201
# Epoch 4/10
# 68/68 [==============================] - 52s 757ms/step - loss: 1.3332 - accuracy: 0.4559
# Epoch 5/10
# 68/68 [==============================] - 52s 766ms/step - loss: 1.2720 - accuracy: 0.4875
# Epoch 6/10
# 68/68 [==============================] - 52s 758ms/step - loss: 1.1768 - accuracy: 0.5344
# Epoch 7/10
# 68/68 [==============================] - 52s 757ms/step - loss: 1.1310 - accuracy: 0.5781
# Epoch 8/10
# 68/68 [==============================] - 52s 762ms/step - loss: 1.1001 - accuracy: 0.5739
# Epoch 9/10
# 68/68 [==============================] - 53s 771ms/step - loss: 0.9469 - accuracy: 0.6441
# Epoch 10/10
# 68/68 [==============================] - 52s 755ms/step - loss: 0.8563 - accuracy: 0.6901

# %% [markdown]
# # TESTING PREDICTION

# %%
import keras.utils as ku
import numpy as np

# %%
test_img = 'Trash-Classifier-in-Python-using-Tensorflow/Data/Test/paper/paper522.jpg'
img = ku.load_img(test_img, target_size = (300,300))
img = ku.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Probability: 0.97152126
# Classified: paper
# Text(0.5, 1.0, 'Loaded Image')

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# CARDBOARD : 0.44 %
# GLASS : 0.29 %
# METAL : 0.61 %
# PAPER : 97.15 %
# PLASTIC : 1.09 %
# TRASH : 0.42 %

# %%
test_img = 'Trash-Classifier-in-Python-using-Tensorflow/Data/Test/metal/metal386.jpg'
img = ku.load_img(test_img, target_size = (300,300))
img = ku.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Probability: 0.40093327
# Classified: metal
# Text(0.5, 1.0, 'Loaded Image')

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# CARDBOARD : 3.52 %
# GLASS : 22.53 %
# METAL : 40.09 %
# PAPER : 6.8100000000000005 %
# PLASTIC : 20.54 %
# TRASH : 6.51 %

# %%
test_img = 'Trash-Classifier-in-Python-using-Tensorflow/Data/Test/plastic/plastic430.jpg'
img = ku.load_img(test_img, target_size = (300,300))
img = ku.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Probability: 0.4993819
# Classified: plastic
# Text(0.5, 1.0, 'Loaded Image')

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# CARDBOARD : 1.95 %
# GLASS : 9.72 %
# METAL : 4.58 %
# PAPER : 2.33 %
# PLASTIC : 81.36 %
# TRASH : 0.08 %

# %%
test_img = 'Trash-Classifier-in-Python-using-Tensorflow/Data/Test/cardboard/cardboard355.jpg'
img = ku.load_img(test_img, target_size = (300,300))
img = ku.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# CARDBOARD : 95.47 %
# GLASS : 1.17 %
# METAL : 0.07 %
# PAPER : 0.04 %
# PLASTIC : 3.08 %
# TRASH : 0.17 %

# %% [markdown]
# # SAVING THE TRAINED MODEL

# %%
model.save('modelnew.h5')
